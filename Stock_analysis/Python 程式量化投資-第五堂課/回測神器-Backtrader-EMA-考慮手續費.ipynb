# %% [markdown]
# <h1>光頭傑夫製作</h1><img src="https://rolqiw.bl.files.1drv.com/y4mYqkObWmQmdJFd8pab8t8m7d_mFhh3_YG63fiAnPaG6gjahHFt0n087pF97x1W2wemm7hd4ZdiPD2OxoPtqcCD_4-Jy-fojnt97kGGWR4Hnq0-9Ny61afd7WVHVTmF_9pcr45OFDFSwLKByeQU1q9TjwKk-HsNmWVsW1eGQ4Gi-9G4pQ5DYoTxswYJ5r5dLF-kKsA1InEyrqmV3kF5pm4WQ?width=658&height=584&cropmode=none" width=160px align="left" />

# %% [markdown]
# ### <span style="color:red ">以下是我們需要的量化分析套件:
# ---
#     1. Jupyter Notebook環境中，第一次安裝過就好，以後直接導入模組就好。
#     2. 如果你是在Colab的環境中運作檔案，請每次安裝

# %% [markdown]
# ! pip install backtrader

# %% [markdown]
# ### <span style="color:red ">以下是我們後續輸出分析結果需要的方程式:
# ---
#     1. 每次你要輸出策略的績效結果時，下面這格你都要跑

# %%
def printTradeAnalysis(analyzer):
    '''
    Function to print the Technical Analysis results in a nice format.
    '''
    #Get the results we are interested in
    total_closed = ''
    total_won =''
    total_lost =''
    win_streak = ''
    lose_streak = ''
    pnl_net =''
    strike_rate =''
    
    if len(analyzer.total)>2:
        total_closed = analyzer.total.closed
        total_won = analyzer.won.total
        total_lost = analyzer.lost.total
        win_streak = analyzer.streak.won.longest
        lose_streak = analyzer.streak.lost.longest
        pnl_net = round(analyzer.pnl.net.total,2)
    
    if total_closed:
        strike_rate=round((total_won / total_closed) * 100,2)
    else:
        strike_rate='沒有完整交易'
    print("策略運作分析結果:")
    print(f'獲利累積次數 : {str(total_won)}')
    print(f'損失累積次數 : {str(total_lost)}')
    print(f'獲利損失次數比 : {str(strike_rate)}')
    print(f'最高連續獲利交易次數 : {str(win_streak)}')
    print(f'最高連續損失交易次數 : {str(lose_streak)}')
    print(f'淨利結算 : {str(pnl_net)}')

# %% [markdown]
# ## <span style="color:red ">  <策略1-with Commision>用EMA做個簡單的回測策略吧!
# ---
# ### 你還記20-day EMA是什麼意思嗎?
#
#     我們測定策略如下:
#     1.如果今天的收盤價高於20-day EMA，那我們就買進一張的股票。
#     2.如果今天的收盤價低於20-day EMA，那我們就賣掉一張的股票。
#     3.任何時候，我們手上最多就一張股票。

# %% [markdown]
# ### <span style="color:red "><策略1.1- with Commision>導入需求模組

# %%
from datetime import datetime
import pandas as pd
import yfinance as yf
import backtrader as bt

# %% [markdown]
# ### <span style="color:red "><策略1.2- with Commision>建立交易策略

# %%
class EmaStrategy(bt.Strategy):
    params = dict(
        ma_period=39,     
    )

    def __init__(self):
        # keep track of close price in the series
        self.data_close = self.datas[0].close

        # keep track of pending orders/buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None

        # add a simple moving average indicator
        self.ema = bt.ind.EMA(self.datas[0], period=self.params.ma_period)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'買單執行 --- 買價: {order.executed.price:.2f}, 成本: {order.executed.value:.2f}, 手續費: {order.executed.comm:.2f}')
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'賣單執行 --- 賣價: {order.executed.price:.2f}, 成本: {order.executed.value:.2f}, 手續費: {order.executed.comm:.2f}')

        # report failed order
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('交易失敗')

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log(f'運作結果 --- 獲利狀況: {trade.pnl:.2f}, 淨獲利: {trade.pnlcomm:.2f}')

    def next(self):
        # do nothing if an order is pending
        if self.order:
            return

        # check if there is already a position
        if not self.position:
            # buy condition
            if self.data_close[0] > self.ema[0]:
                self.log(f'開出買單 --- 當時市場價格: {self.data_close[0]:.2f}')
                self.order = self.buy(size=1000)
        else:
            # sell condition
            if self.data_close[0] < self.ema[0]:
                self.log(f'開出賣單 --- 當時市場價格: {self.data_close[0]:.2f}')
                self.order = self.sell(size=1000)

# %% [markdown]
# ### <span style="color:red "><策略1.3- with Commision>抓取目標股票的歷史資料

# %%
data= yf.download(  '2330.tw',              #股票代碼
                    start='2022-3-30',      #資料開始日期
                    end='2023-3-30',         #資料結束日期
                    progress=False
                 )
print(data)
data=bt.feeds.PandasData(dataname=pd.DataFrame({'open': data['Open'], 
                   'high': data['High'],
                   'low': data['Low'],
                   'close': data['Close'],
                   'volume': data['Volume'],
                  }))
# Out:
#              Open   High    Low  Close   Adj Close    Volume
# Date
# 2022-03-30  599.0  600.0  597.0  600.0  586.769043  41230239
# 2022-03-31  602.0  602.0  594.0  597.0  583.835144  22700114
# 2022-04-01  585.0  589.0  584.0  589.0  576.011536  29732696
# 2022-04-06  578.0  580.0  575.0  578.0  565.254211  37645873
# 2022-04-07  571.0  573.0  566.0  566.0  553.518799  42904743
# ...           ...    ...    ...    ...         ...       ...
# 2023-03-22  524.0  533.0  524.0  533.0  533.000000  42385987
# 2023-03-23  528.0  539.0  528.0  538.0  538.000000  26728246
# 2023-03-24  536.0  539.0  535.0  539.0  539.000000  21926240
# 2023-03-27  533.0  536.0  531.0  531.0  531.000000  16111177
# 2023-03-28  525.0  530.0  524.0  525.0  525.000000  17234120
#
# [243 rows x 6 columns]

# %% [markdown]
# ### <span style="color:red "><策略1.4- with Commision>建立台股交易費用計算模式

# %%
class TWStockCommisionScheme(bt.CommInfoBase):
    params = (
        
         ('stocklike', True),
         ('commtype', bt.CommInfoBase.COMM_PERC),
         ('percabs', True),
         ('discount', 0.3),
         ('tax',0.003),
         ('lowestfee',20)
        )

    def _getcommission(self, size, price, pseudoexec):
          if size>0:
            return max(self.p.lowestfee,size * price * self.p.commission * self.p.discount)
          else:
            return (max(self.p.lowestfee,-(size * price * self.p.commission * self.p.discount))-size * price *self.p.tax)

# %% [markdown]
# ### <span style="color:red "><策略1.5- with Commision>建立回測分析「大腦」

# %%
#設立投資本金
#你可以根據你想要模擬的投資標的股價作適當調整
cash=1000000

# create a Cerebro entity
cerebro = bt.Cerebro()

# set up the backtest
cerebro.adddata(data)
cerebro.addstrategy(EmaStrategy)
cerebro.broker.setcash(cash)

#commission手續費 0.1425%
#discount 你可以拿到的手續費折數
#tax=0.003 證券交易稅率
comminfo = TWStockCommisionScheme(
    commission=0.001425,  
    discount=0.2,
    tax=0.003,
    lowestfee=20
)

cerebro.broker.addcommissioninfo(comminfo)

# %% [markdown]
# ### <span style="color:red "><策略1.6- with Commision>讓Analyzers來幫我診斷策略細節...-開始回測

# %%
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name="ta")

strategies = cerebro.run()
firstStrat = strategies[0]

# print the analyzers
printTradeAnalysis(firstStrat.analyzers.ta.get_analysis())
print(f'持有資產總值: {cerebro.broker.getvalue():.2f}')
# Out:
# 2022-05-30, 開出買單 --- 當時市場價格: 547.00
# 2022-05-31, 買單執行 --- 買價: 542.00, 成本: 542000.00, 手續費: 154.47
# 2022-06-02, 開出賣單 --- 當時市場價格: 540.00
# 2022-06-06, 賣單執行 --- 賣價: 541.00, 成本: 542000.00, 手續費: 1777.18
# 2022-06-06, 運作結果 --- 獲利狀況: -1000.00, 淨獲利: -2931.65
# 2022-07-18, 開出買單 --- 當時市場價格: 495.50
# 2022-07-19, 買單執行 --- 買價: 487.50, 成本: 487500.00, 手續費: 138.94
# 2022-07-19, 開出賣單 --- 當時市場價格: 491.00
# 2022-07-20, 賣單執行 --- 賣價: 502.00, 成本: 487500.00, 手續費: 1649.07
# 2022-07-20, 運作結果 --- 獲利狀況: 14500.00, 淨獲利: 12711.99
# 2022-07-20, 開出買單 --- 當時市場價格: 495.00
# 2022-07-21, 買單執行 --- 買價: 496.00, 成本: 496000.00, 手續費: 141.36
# 2022-07-26, 開出賣單 --- 當時市場價格: 495.00
# 2022-07-27, 賣單執行 --- 賣價: 494.00, 成本: 496000.00, 手續費: 1622.79
# 2022-07-27, 運作結果 --- 獲利狀況: -2000.00, 淨獲利: -3764.15
# 2022-07-27, 開出買單 --- 當時市場價格: 502.00
# 2022-07-28, 買單執行 --- 買價: 509.00, 成本: 509000.00, 手續費: 145.07
# 2022-08-02, 開出賣單 --- 當時市場價格: 492.00
# 2022-08-03, 賣單執行 --- 賣價: 494.00, 成本: 509000.00, 手續費: 1622.79
# 2022-08-03, 運作結果 --- 獲利狀況: -15000.00, 淨獲利: -16767.85
# 2022-08-03, 開出買單 --- 當時市場價格: 501.00
# 2022-08-04, 買單執行 --- 買價: 499.00, 成本: 499000.00, 手續費: 142.22
# 2022-08-23, 開出賣單 --- 當時市場價格: 504.00
# 2022-08-24, 賣單執行 --- 賣價: 504.00, 成本: 499000.00, 手續費: 1655.64
# 2022-08-24, 運作結果 --- 獲利狀況: 5000.00, 淨獲利: 3202.14
# 2022-08-25, 開出買單 --- 當時市場價格: 508.00
# 2022-08-26, 買單執行 --- 買價: 513.00, 成本: 513000.00, 手續費: 146.21
# 2022-08-29, 開出賣單 --- 當時市場價格: 498.50
# 2022-08-30, 賣單執行 --- 賣價: 497.50, 成本: 513000.00, 手續費: 1634.29
# 2022-08-30, 運作結果 --- 獲利狀況: -15500.00, 淨獲利: -17280.49
# 2022-11-09, 開出買單 --- 當時市場價格: 417.00
# 2022-11-10, 買單執行 --- 買價: 409.00, 成本: 409000.00, 手續費: 116.57
# 2022-11-10, 開出賣單 --- 當時市場價格: 407.50
# 2022-11-11, 賣單執行 --- 賣價: 441.50, 成本: 409000.00, 手續費: 1450.33
# 2022-11-11, 運作結果 --- 獲利狀況: 32500.00, 淨獲利: 30933.11
# 2022-11-11, 開出買單 --- 當時市場價格: 441.50
# 2022-11-14, 買單執行 --- 買價: 450.00, 成本: 450000.00, 手續費: 128.25
# 2022-12-20, 開出賣單 --- 當時市場價格: 457.50
# 2022-12-21, 賣單執行 --- 賣價: 460.00, 成本: 450000.00, 手續費: 1511.10
# 2022-12-21, 運作結果 --- 獲利狀況: 10000.00, 淨獲利: 8360.65
# 2022-12-22, 開出買單 --- 當時市場價格: 468.00
# 2022-12-23, 買單執行 --- 買價: 457.50, 成本: 457500.00, 手續費: 130.39
# 2022-12-23, 開出賣單 --- 當時市場價格: 455.00
# 2022-12-26, 賣單執行 --- 賣價: 454.00, 成本: 457500.00, 手續費: 1491.39
# 2022-12-26, 運作結果 --- 獲利狀況: -3500.00, 淨獲利: -5121.78
# 2023-01-09, 開出買單 --- 當時市場價格: 481.00
# 2023-01-10, 買單執行 --- 買價: 486.00, 成本: 486000.00, 手續費: 138.51
# 2023-03-14, 開出賣單 --- 當時市場價格: 510.00
# 2023-03-15, 賣單執行 --- 賣價: 515.00, 成本: 486000.00, 手續費: 1691.78
# 2023-03-15, 運作結果 --- 獲利狀況: 29000.00, 淨獲利: 27169.72
# 2023-03-15, 開出買單 --- 當時市場價格: 511.00
# 2023-03-16, 買單執行 --- 買價: 505.00, 成本: 505000.00, 手續費: 143.93
# 2023-03-16, 開出賣單 --- 當時市場價格: 505.00
# 2023-03-17, 賣單執行 --- 賣價: 516.00, 成本: 505000.00, 手續費: 1695.06
# 2023-03-17, 運作結果 --- 獲利狀況: 11000.00, 淨獲利: 9161.01
# 2023-03-17, 開出買單 --- 當時市場價格: 518.00
# 2023-03-20, 買單執行 --- 買價: 517.00, 成本: 517000.00, 手續費: 147.34
# 策略運作分析結果:
# 獲利累積次數 : 6
# 損失累積次數 : 5
# 獲利損失次數比 : 54.55
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 45672.69
# 持有資產總值: 1053525.35

# %% [markdown]
# ### <span style="color:red "><策略1.7- with Commision>畫張圖勝過千言萬語!-圖形化表達

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi']=80

cerebro.plot(iplot=True, volume=True)
# Out:
# <img src="data:image/png;base64,..." width="892.8">
# [[<Figure size 512x384 with 4 Axes>]]

# %% [markdown]
# ### <span style="color:red "><策略2- with Commision>我們不得不懷疑20-day EMA是一個好選擇嗎?
# --------
#     你有想過一個問題?幾日均線說穿了都是人說的一個故事。那既然是人定的，為何不讓機器來告訴我，屬於台積電的財富均線應該是幾日比較好呢?

# %% [markdown]
# ### <span style="color:red "><策略2.2- with Commision>建立交易策略

# %%
class EmaStrategy(bt.Strategy):
    params = dict(
        ma_period=20,   
        totalValue=''
     )

    def __init__(self):
        # keep track of close price in the series
        self.data_close = self.datas[0].close

        # keep track of pending orders
        self.order = None

        # add a simple moving average indicator
        self.ema = bt.ind.EMA(self.datas[0], period=self.params.ma_period)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        # set no pending order
        self.order = None

    def next(self):
        # do nothing if an order is pending
        if self.order:
            return

        # check if there is already a position
        if not self.position:
            # buy condition
            if self.data_close[0] > self.ema[0]:
                self.order = self.buy(size=1000)
        else:
            # sell condition
            if self.data_close[0] < self.ema[0]:
                self.order = self.sell(size=1000)

    def stop(self):
        self.log(f'(EMA週期設定 = {self.params.ma_period:2d}) --- 淨利數值: {self.broker.getvalue()-cash:.2f}')
        self.params.totalValue=self.broker.getvalue()

# %% [markdown]
# ### <span style="color:red "><策略2.4- with Commision>建立台股交易費用計算模式

# %%
class TWStockCommisionScheme(bt.CommInfoBase):
    params = (
        
         ('stocklike', True),
         ('commtype', bt.CommInfoBase.COMM_PERC),
         ('percabs', True),
         ('discount', 0.3),
         ('tax',0.003),
         ('lowestfee',20)
        )

    def _getcommission(self, size, price, pseudoexec):
          if size>0:
            return max(self.p.lowestfee,size * price * self.p.commission * self.p.discount)
          else:
            return (max(self.p.lowestfee,-(size * price * self.p.commission * self.p.discount))-size * price *self.p.tax)

# %% [markdown]
# ### <span style="color:red "><策略2.5- with Commision>建立回測分析「大腦」,讓Analyzers來幫我診斷策略細節...-開始回測

# %%
#設立投資本金
#你可以根據你想要模擬的投資標的股價作適當調整
cash=1000000

# create a Cerebro entity
cerebro = bt.Cerebro()
cerebro.optstrategy(EmaStrategy, ma_period=range(5, 61))
cerebro.adddata(data)
cerebro.broker.setcash(cash)


#commission手續費 0.1425%
#discount 你可以拿到的手續費折數
#tax=0.003 證券交易稅率
comminfo = TWStockCommisionScheme(
    commission=0.001425,  
    discount=0.2,
    tax=0.003,
    lowestfee=20
)

cerebro.broker.addcommissioninfo(comminfo)

cerebro.addanalyzer(bt.analyzers.TradeAnalyzer,_name="ta")
# win系統下，請固定用單核去跑。其他系統可以試試看多核
opt_runs = cerebro.run(maxcpus=1)



for run in opt_runs:
    for strategy in run:
        print(f'EMA週期設定:{strategy.params.ma_period}')
        try:
            printTradeAnalysis(strategy.analyzers.ta.get_analysis())
        except KeyError :
            print('沒有交易發生')
        print(f'持有資產總值: {strategy.params.totalValue:.2f}')
        print('--------------------------------------------------------')
# Out:
# 2023-03-28, (EMA週期設定 =  5) --- 淨利數值: -104688.97
# 2023-03-28, (EMA週期設定 =  6) --- 淨利數值: -58502.23
# 2023-03-28, (EMA週期設定 =  7) --- 淨利數值: -5614.33
# 2023-03-28, (EMA週期設定 =  8) --- 淨利數值: -8488.30
# 2023-03-28, (EMA週期設定 =  9) --- 淨利數值: -7498.31
# 2023-03-28, (EMA週期設定 = 10) --- 淨利數值: 10563.33
# 2023-03-28, (EMA週期設定 = 11) --- 淨利數值: 23058.38
# 2023-03-28, (EMA週期設定 = 12) --- 淨利數值: 40698.00
# 2023-03-28, (EMA週期設定 = 13) --- 淨利數值: 42169.86
# 2023-03-28, (EMA週期設定 = 14) --- 淨利數值: 30332.04
# 2023-03-28, (EMA週期設定 = 15) --- 淨利數值: 35693.34
# 2023-03-28, (EMA週期設定 = 16) --- 淨利數值: 10584.89
# 2023-03-28, (EMA週期設定 = 17) --- 淨利數值: 55633.56
# 2023-03-28, (EMA週期設定 = 18) --- 淨利數值: 62455.68
# 2023-03-28, (EMA週期設定 = 19) --- 淨利數值: 57472.11
# 2023-03-28, (EMA週期設定 = 20) --- 淨利數值: 42967.98
# 2023-03-28, (EMA週期設定 = 21) --- 淨利數值: 17367.89
# 2023-03-28, (EMA週期設定 = 22) --- 淨利數值: 11866.32
# 2023-03-28, (EMA週期設定 = 23) --- 淨利數值: 19419.61
# 2023-03-28, (EMA週期設定 = 24) --- 淨利數值: -5555.38
# 2023-03-28, (EMA週期設定 = 25) --- 淨利數值: 3281.59
# 2023-03-28, (EMA週期設定 = 26) --- 淨利數值: 1786.52
# 2023-03-28, (EMA週期設定 = 27) --- 淨利數值: -3335.26
# 2023-03-28, (EMA週期設定 = 28) --- 淨利數值: -1172.67
# 2023-03-28, (EMA週期設定 = 29) --- 淨利數值: 820.76
# 2023-03-28, (EMA週期設定 = 30) --- 淨利數值: -9257.81
# 2023-03-28, (EMA週期設定 = 31) --- 淨利數值: 2702.76
# 2023-03-28, (EMA週期設定 = 32) --- 淨利數值: 19506.32
# 2023-03-28, (EMA週期設定 = 33) --- 淨利數值: 14522.74
# 2023-03-28, (EMA週期設定 = 34) --- 淨利數值: 14522.74
# 2023-03-28, (EMA週期設定 = 35) --- 淨利數值: 18563.15
# 2023-03-28, (EMA週期設定 = 36) --- 淨利數值: 18563.15
# 2023-03-28, (EMA週期設定 = 37) --- 淨利數值: 51237.81
# 2023-03-28, (EMA週期設定 = 38) --- 淨利數值: 51237.81
# 2023-03-28, (EMA週期設定 = 39) --- 淨利數值: 53525.35
# 2023-03-28, (EMA週期設定 = 40) --- 淨利數值: 22592.24
# 2023-03-28, (EMA週期設定 = 41) --- 淨利數值: 877.68
# 2023-03-28, (EMA週期設定 = 42) --- 淨利數值: -15288.90
# 2023-03-28, (EMA週期設定 = 43) --- 淨利數值: -13119.17
# 2023-03-28, (EMA週期設定 = 44) --- 淨利數值: -8186.94
# 2023-03-28, (EMA週期設定 = 45) --- 淨利數值: -8186.94
# 2023-03-28, (EMA週期設定 = 46) --- 淨利數值: -8186.94
# 2023-03-28, (EMA週期設定 = 47) --- 淨利數值: -8186.94
# 2023-03-28, (EMA週期設定 = 48) --- 淨利數值: -2705.01
# 2023-03-28, (EMA週期設定 = 49) --- 淨利數值: -5522.42
# 2023-03-28, (EMA週期設定 = 50) --- 淨利數值: -5522.42
# 2023-03-28, (EMA週期設定 = 51) --- 淨利數值: -8519.71
# 2023-03-28, (EMA週期設定 = 52) --- 淨利數值: -8519.71
# 2023-03-28, (EMA週期設定 = 53) --- 淨利數值: -5705.86
# 2023-03-28, (EMA週期設定 = 54) --- 淨利數值: -580.10
# 2023-03-28, (EMA週期設定 = 55) --- 淨利數值: -580.10
# 2023-03-28, (EMA週期設定 = 56) --- 淨利數值: -580.10
# 2023-03-28, (EMA週期設定 = 57) --- 淨利數值: 15424.46
# 2023-03-28, (EMA週期設定 = 58) --- 淨利數值: 15424.46
# 2023-03-28, (EMA週期設定 = 59) --- 淨利數值: 15424.46
# 2023-03-28, (EMA週期設定 = 60) --- 淨利數值: 15424.46
# EMA週期設定:5
# 策略運作分析結果:
# 獲利累積次數 : 10
# 損失累積次數 : 24
# 獲利損失次數比 : 29.41
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 5
# 淨利結算 : -105539.63
# 持有資產總值: 895311.03
# --------------------------------------------------------
# EMA週期設定:6
# 策略運作分析結果:
# 獲利累積次數 : 9
# 損失累積次數 : 22
# 獲利損失次數比 : 29.03
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 6
# 淨利結算 : -59352.89
# 持有資產總值: 941497.77
# --------------------------------------------------------
# EMA週期設定:7
# 策略運作分析結果:
# 獲利累積次數 : 8
# 損失累積次數 : 18
# 獲利損失次數比 : 30.77
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 6
# 淨利結算 : -6464.99
# 持有資產總值: 994385.67
# --------------------------------------------------------
# EMA週期設定:8
# 策略運作分析結果:
# 獲利累積次數 : 6
# 損失累積次數 : 17
# 獲利損失次數比 : 26.09
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 6
# 淨利結算 : -9338.96
# 持有資產總值: 991511.70
# --------------------------------------------------------
# EMA週期設定:9
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 17
# 獲利損失次數比 : 22.73
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 7
# 淨利結算 : -8348.97
# 持有資產總值: 992501.69
# --------------------------------------------------------
# EMA週期設定:10
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 15
# 獲利損失次數比 : 25.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 6
# 淨利結算 : 9712.66
# 持有資產總值: 1010563.33
# --------------------------------------------------------
# EMA週期設定:11
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 14
# 獲利損失次數比 : 26.32
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 5
# 淨利結算 : 22207.72
# 持有資產總值: 1023058.38
# --------------------------------------------------------
# EMA週期設定:12
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 13
# 獲利損失次數比 : 27.78
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 5
# 淨利結算 : 39847.34
# 持有資產總值: 1040698.00
# --------------------------------------------------------
# EMA週期設定:13
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 13
# 獲利損失次數比 : 27.78
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 5
# 淨利結算 : 41319.2
# 持有資產總值: 1042169.86
# --------------------------------------------------------
# EMA週期設定:14
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 14
# 獲利損失次數比 : 26.32
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 5
# 淨利結算 : 29481.37
# 持有資產總值: 1030332.04
# --------------------------------------------------------
# EMA週期設定:15
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 13
# 獲利損失次數比 : 27.78
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 4
# 淨利結算 : 34842.68
# 持有資產總值: 1035693.34
# --------------------------------------------------------
# EMA週期設定:16
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 12
# 獲利損失次數比 : 29.41
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 4
# 淨利結算 : 9734.23
# 持有資產總值: 1010584.89
# --------------------------------------------------------
# EMA週期設定:17
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 9
# 獲利損失次數比 : 35.71
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 54782.9
# 持有資產總值: 1055633.56
# --------------------------------------------------------
# EMA週期設定:18
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 8
# 獲利損失次數比 : 38.46
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 61605.03
# 持有資產總值: 1062455.68
# --------------------------------------------------------
# EMA週期設定:19
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 9
# 獲利損失次數比 : 30.77
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 56621.45
# 持有資產總值: 1057472.11
# --------------------------------------------------------
# EMA週期設定:20
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 10
# 獲利損失次數比 : 23.08
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 4
# 淨利結算 : 42117.32
# 持有資產總值: 1042967.98
# --------------------------------------------------------
# EMA週期設定:21
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 10
# 獲利損失次數比 : 23.08
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 4
# 淨利結算 : 16517.23
# 持有資產總值: 1017367.89
# --------------------------------------------------------
# EMA週期設定:22
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 10
# 獲利損失次數比 : 23.08
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 4
# 淨利結算 : 11015.66
# 持有資產總值: 1011866.32
# --------------------------------------------------------
# EMA週期設定:23
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 8
# 獲利損失次數比 : 27.27
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 4
# 淨利結算 : 18568.95
# 持有資產總值: 1019419.61
# --------------------------------------------------------
# EMA週期設定:24
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 8
# 獲利損失次數比 : 27.27
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 4
# 淨利結算 : -6406.04
# 持有資產總值: 994444.62
# --------------------------------------------------------
# EMA週期設定:25
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 7
# 獲利損失次數比 : 30.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 2430.93
# 持有資產總值: 1003281.59
# --------------------------------------------------------
# EMA週期設定:26
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 7
# 獲利損失次數比 : 30.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 935.86
# 持有資產總值: 1001786.52
# --------------------------------------------------------
# EMA週期設定:27
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 8
# 獲利損失次數比 : 27.27
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -4185.92
# 持有資產總值: 996664.74
# --------------------------------------------------------
# EMA週期設定:28
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 8
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -2023.33
# 持有資產總值: 998827.33
# --------------------------------------------------------
# EMA週期設定:29
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 8
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -29.9
# 持有資產總值: 1000820.76
# --------------------------------------------------------
# EMA週期設定:30
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 8
# 獲利損失次數比 : 38.46
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : -10108.47
# 持有資產總值: 990742.19
# --------------------------------------------------------
# EMA週期設定:31
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 8
# 獲利損失次數比 : 38.46
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 1852.11
# 持有資產總值: 1002702.76
# --------------------------------------------------------
# EMA週期設定:32
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 7
# 獲利損失次數比 : 41.67
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 18655.66
# 持有資產總值: 1019506.32
# --------------------------------------------------------
# EMA週期設定:33
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 7
# 獲利損失次數比 : 41.67
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 13672.08
# 持有資產總值: 1014522.74
# --------------------------------------------------------
# EMA週期設定:34
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 7
# 獲利損失次數比 : 41.67
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : 13672.08
# 持有資產總值: 1014522.74
# --------------------------------------------------------
# EMA週期設定:35
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 7
# 獲利損失次數比 : 41.67
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 17712.49
# 持有資產總值: 1018563.15
# --------------------------------------------------------
# EMA週期設定:36
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 7
# 獲利損失次數比 : 41.67
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 17712.49
# 持有資產總值: 1018563.15
# --------------------------------------------------------
# EMA週期設定:37
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 5
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 43385.15
# 持有資產總值: 1051237.81
# --------------------------------------------------------
# EMA週期設定:38
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 5
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 43385.15
# 持有資產總值: 1051237.81
# --------------------------------------------------------
# EMA週期設定:39
# 策略運作分析結果:
# 獲利累積次數 : 6
# 損失累積次數 : 5
# 獲利損失次數比 : 54.55
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 45672.69
# 持有資產總值: 1053525.35
# --------------------------------------------------------
# EMA週期設定:40
# 策略運作分析結果:
# 獲利累積次數 : 5
# 損失累積次數 : 5
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : 14739.59
# 持有資產總值: 1022592.24
# --------------------------------------------------------
# EMA週期設定:41
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 5
# 獲利損失次數比 : 44.44
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 3
# 淨利結算 : -6974.97
# 持有資產總值: 1000877.68
# --------------------------------------------------------
# EMA週期設定:42
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -23141.55
# 持有資產總值: 984711.10
# --------------------------------------------------------
# EMA週期設定:43
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 6
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -20971.82
# 持有資產總值: 986880.83
# --------------------------------------------------------
# EMA週期設定:44
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -16039.59
# 持有資產總值: 991813.06
# --------------------------------------------------------
# EMA週期設定:45
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -16039.59
# 持有資產總值: 991813.06
# --------------------------------------------------------
# EMA週期設定:46
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -16039.59
# 持有資產總值: 991813.06
# --------------------------------------------------------
# EMA週期設定:47
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -16039.59
# 持有資產總值: 991813.06
# --------------------------------------------------------
# EMA週期設定:48
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -10557.66
# 持有資產總值: 997294.99
# --------------------------------------------------------
# EMA週期設定:49
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 5
# 獲利損失次數比 : 44.44
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -13375.08
# 持有資產總值: 994477.58
# --------------------------------------------------------
# EMA週期設定:50
# 策略運作分析結果:
# 獲利累積次數 : 4
# 損失累積次數 : 5
# 獲利損失次數比 : 44.44
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -13375.08
# 持有資產總值: 994477.58
# --------------------------------------------------------
# EMA週期設定:51
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 6
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -16372.36
# 持有資產總值: 991480.29
# --------------------------------------------------------
# EMA週期設定:52
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 6
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 3
# 淨利結算 : -16372.36
# 持有資產總值: 991480.29
# --------------------------------------------------------
# EMA週期設定:53
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 5
# 獲利損失次數比 : 37.5
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -13558.52
# 持有資產總值: 994294.14
# --------------------------------------------------------
# EMA週期設定:54
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -39441.59
# 持有資產總值: 999419.90
# --------------------------------------------------------
# EMA週期設定:55
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -39441.59
# 持有資產總值: 999419.90
# --------------------------------------------------------
# EMA週期設定:56
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -39441.59
# 持有資產總值: 999419.90
# --------------------------------------------------------
# EMA週期設定:57
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -23437.03
# 持有資產總值: 1015424.46
# --------------------------------------------------------
# EMA週期設定:58
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -23437.03
# 持有資產總值: 1015424.46
# --------------------------------------------------------
# EMA週期設定:59
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -23437.03
# 持有資產總值: 1015424.46
# --------------------------------------------------------
# EMA週期設定:60
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 1
# 最高連續損失交易次數 : 2
# 淨利結算 : -23437.03
# 持有資產總值: 1015424.46
# --------------------------------------------------------

# %% [markdown]
# ### <span style="color:red "><策略3- with Commision>技術分析不是一直說什麼黃金交叉...什麼死亡交叉...
# -----
#     1.黃金交叉：短天期均線向上與長天期交叉，稱為黃金交叉。
#     2.死亡交叉：短天期均線向下與長天期交叉，稱為死亡交叉。

# %% [markdown]
# ### <span style="color:red "><策略3.2- with Commision>建立交易策略

# %%
class EmaCross(bt.Strategy):
    params = dict(
        pfast=5,   # 短期均線週期
        pslow=13   # 長期均線週期
    )

    def __init__(self):
        self.data_close = self.datas[0].close
        
        self.order = None
        self.price = None
        self.comm = None

        
        ema1 = bt.ind.EMA(self.datas[0],period=self.p.pfast)  # 短期均線
        ema2 = bt.ind.EMA(self.datas[0],period=self.p.pslow)  # 長期均線
        self.crossover = bt.ind.CrossOver(ema1, ema2)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'買單執行 --- 買價: {order.executed.price:.2f}, 成本: {order.executed.value:.2f}, 手續費: {order.executed.comm:.2f}')
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'賣單執行 --- 賣價: {order.executed.price:.2f}, 成本: {order.executed.value:.2f}, 手續費: {order.executed.comm:.2f}')

        # report failed order
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('交易失敗')

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log(f'運作結果 --- 獲利狀況: {trade.pnl:.2f}, 淨獲利: {trade.pnlcomm:.2f}')

    def next(self):
        # do nothing if an order is pending
        if self.order:
            return

        # check if there is already a position
        if not self.position:
            # buy condition
            if self.crossover > 0:
                self.log(f'開出買單 --- 當時市場價格: {self.data_close[0]:.2f}')
                self.order = self.buy(size=1000)
        else:
            # sell condition
            if self.crossover < 0:
                self.log(f'開出賣單 --- 當時市場價格: {self.data_close[0]:.2f}')
                self.order = self.sell(size=1000)
    def stop(self):
        self.log(f'(EMA週期設定 = 短週期:{self.p.pfast:2d},長週期:{self.p.pslow:2d}) --- 最終資產價值: {self.broker.getvalue():.2f}')

# %% [markdown]
# ### <span style="color:red "><策略3.4- with Commision>建立台股交易費用計算模式

# %%
class TWStockCommisionScheme(bt.CommInfoBase):
    params = (
        
         ('stocklike', True),
         ('commtype', bt.CommInfoBase.COMM_PERC),
         ('percabs', True),
         ('discount', 0.3),
         ('tax',0.003),
         ('lowestfee',20)
        )

    def _getcommission(self, size, price, pseudoexec):
          if size>0:
            return max(self.p.lowestfee,size * price * self.p.commission * self.p.discount)
          else:
            return (max(self.p.lowestfee,-(size * price * self.p.commission * self.p.discount))-size * price *self.p.tax)

# %% [markdown]
# ### <span style="color:red "><策略3.5- with Commision>建立回測分析「大腦」

# %%
#設立投資本金
#你可以根據你想要模擬的投資標的股價作適當調整
cash=1000000

cerebro = bt.Cerebro()
# set up the backtest
cerebro.adddata(data)
cerebro.broker.setcash(cash)
cerebro.addstrategy(EmaCross)

#commission手續費 0.1425%
#discount 你可以拿到的手續費折數
#tax=0.003 證券交易稅率
comminfo = TWStockCommisionScheme(
    commission=0.001425,  
    discount=0.2,
    tax=0.003,
    lowestfee=20
)

cerebro.broker.addcommissioninfo(comminfo)

# %% [markdown]
# ### <span style="color:red "><策略3.6- with Commision>讓Analyzers來幫我診斷策略細節...-開始回測

# %%
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name="ta")

strategies = cerebro.run()
firstStrat = strategies[0]

# print the analyzers
printTradeAnalysis(firstStrat.analyzers.ta.get_analysis())
print(f'持有資產總值: {firstStrat.broker.getvalue():.2f}')
# Out:
# 2022-05-30, 開出買單 --- 當時市場價格: 547.00
# 2022-05-31, 買單執行 --- 買價: 542.00, 成本: 542000.00, 手續費: 154.47
# 2022-06-13, 開出賣單 --- 當時市場價格: 516.00
# 2022-06-14, 賣單執行 --- 賣價: 507.00, 成本: 542000.00, 手續費: 1665.49
# 2022-06-14, 運作結果 --- 獲利狀況: -35000.00, 淨獲利: -36819.96
# 2022-07-15, 開出買單 --- 當時市場價格: 492.50
# 2022-07-18, 買單執行 --- 買價: 495.50, 成本: 495500.00, 手續費: 141.22
# 2022-08-24, 開出賣單 --- 當時市場價格: 503.00
# 2022-08-25, 賣單執行 --- 賣價: 505.00, 成本: 495500.00, 手續費: 1658.92
# 2022-08-25, 運作結果 --- 獲利狀況: 9500.00, 淨獲利: 7699.86
# 2022-11-09, 開出買單 --- 當時市場價格: 417.00
# 2022-11-10, 買單執行 --- 買價: 409.00, 成本: 409000.00, 手續費: 116.57
# 2022-12-08, 開出賣單 --- 當時市場價格: 471.50
# 2022-12-09, 賣單執行 --- 賣價: 478.00, 成本: 409000.00, 手續費: 1570.23
# 2022-12-09, 運作結果 --- 獲利狀況: 69000.00, 淨獲利: 67313.21
# 2022-12-09, 開出買單 --- 當時市場價格: 481.50
# 2022-12-12, 買單執行 --- 買價: 476.50, 成本: 476500.00, 手續費: 135.80
# 2022-12-12, 開出賣單 --- 當時市場價格: 475.00
# 2022-12-13, 賣單執行 --- 賣價: 473.00, 成本: 476500.00, 手續費: 1553.81
# 2022-12-13, 運作結果 --- 獲利狀況: -3500.00, 淨獲利: -5189.61
# 2023-01-09, 開出買單 --- 當時市場價格: 481.00
# 2023-01-10, 買單執行 --- 買價: 486.00, 成本: 486000.00, 手續費: 138.51
# 2023-02-20, 開出賣單 --- 當時市場價格: 517.00
# 2023-02-21, 賣單執行 --- 賣價: 515.00, 成本: 486000.00, 手續費: 1691.78
# 2023-02-21, 運作結果 --- 獲利狀況: 29000.00, 淨獲利: 27169.72
# 2023-03-07, 開出買單 --- 當時市場價格: 524.00
# 2023-03-08, 買單執行 --- 買價: 521.00, 成本: 521000.00, 手續費: 148.49
# 2023-03-10, 開出賣單 --- 當時市場價格: 513.00
# 2023-03-13, 賣單執行 --- 賣價: 513.00, 成本: 521000.00, 手續費: 1685.20
# 2023-03-13, 運作結果 --- 獲利狀況: -8000.00, 淨獲利: -9833.69
# 2023-03-22, 開出買單 --- 當時市場價格: 533.00
# 2023-03-23, 買單執行 --- 買價: 528.00, 成本: 528000.00, 手續費: 150.48
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:13) --- 最終資產價值: 1047189.04
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 50339.51
# 持有資產總值: 1047189.04

# %% [markdown]
# ### <span style="color:red "><策略3.7- with Commision>畫張圖勝過千言萬語!-圖形化表達

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi']=80

# plot results
cerebro.plot(iplot=True, volume=False)
# Out:
# <img src="data:image/png;base64,..." width="834.4">
# [[<Figure size 512x384 with 4 Axes>]]

# %% [markdown]
# ### <span style="color:red "><策略4- with Commision>上面是5日線和10日線的交叉結果，那如果我想要知道哪兩條線的配對交叉結果最好...
# -----
# ###     我就是想知道:
#         到底是EMA5穿過EMA20比較厲害?
#         還是EMA20穿出EMA60比較厲害?

# %% [markdown]
# ### <span style="color:red "><策略4.2- with Commision>建立交易策略

# %%
class EmaCross(bt.Strategy):
    params = dict(
        pfast=5,   # 短期均線週期
        pslow=10,   # 長期均線週期
        totalValue=''
    )

    def __init__(self):
        self.data_close = self.datas[0].close
        
        self.order = None
        self.price = None
        self.comm = None

        
        ema1 = bt.ind.EMA(self.datas[0],period=self.p.pfast)  # 短期均線
        ema2 = bt.ind.EMA(self.datas[0],period=self.p.pslow)  # 長期均線
        self.crossover = bt.ind.CrossOver(ema1, ema2)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.price = order.executed.price
                self.comm = order.executed.comm

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return


    def next(self):
        # do nothing if an order is pending
        if self.order:
            return

        # check if there is already a position
        if not self.position:
            # buy condition
            if self.crossover > 0:
                self.order = self.buy(size=1000)
        else:
            # sell condition
            if self.crossover < 0:
                self.order = self.sell(size=1000)
    def stop(self):
        self.log(f'(EMA週期設定 = 短週期:{self.p.pfast:2d},長週期:{self.p.pslow:2d}) --- 淨利數值: {self.broker.getvalue()-cash:.2f}')
        self.params.totalValue=self.broker.getvalue()

# %% [markdown]
# ### <span style="color:red "><策略4.4- with Commision>建立台股交易費用計算模式

# %%
class TWStockCommisionScheme(bt.CommInfoBase):
    params = (
        
         ('stocklike', True),
         ('commtype', bt.CommInfoBase.COMM_PERC),
         ('percabs', True),
         ('discount', 0.3),
         ('tax',0.003),
         ('lowestfee',20)
        )

    def _getcommission(self, size, price, pseudoexec):
          if size>0:
            return max(self.p.lowestfee,size * price * self.p.commission * self.p.discount)
          else:
            return (max(self.p.lowestfee,-(size * price * self.p.commission * self.p.discount))-size * price *self.p.tax)

# %% [markdown]
# ### <span style="color:red "><策略4.5- with Commision>建立回測分析「大腦」,讓Analyzers來幫我診斷策略細節...-開始回測

# %%
#設立投資本金
#你可以根據你想要模擬的投資標的股價作適當調整
cash=1000000

cerebro = bt.Cerebro()
cerebro.optstrategy(EmaCross, pfast=range(5,9),pslow=range(10,25))
cerebro.adddata(data)
cerebro.broker.setcash(cash)


#commission手續費 0.1425%
#discount 你可以拿到的手續費折數
#tax=0.003 證券交易稅率
comminfo = TWStockCommisionScheme(
    commission=0.001425,  
    discount=0.2,
    tax=0.003,
    lowestfee=20
)

cerebro.broker.addcommissioninfo(comminfo)

cerebro.addanalyzer(bt.analyzers.TradeAnalyzer,_name="ta")
# win系統下，請固定用單核去跑。其他系統可以試試看多核
opt_runs = cerebro.run(maxcpus=1)


for run in opt_runs:
    for strategy in run:
        print(f'EMA短週期設定:{strategy.params.pfast} EMA長週期設定:{strategy.params.pslow}')
        try:
            printTradeAnalysis(strategy.analyzers.ta.get_analysis())
        except KeyError :
            print('沒有交易發生')
        print(f'持有資產總值: {strategy.params.totalValue:.2f}')
        print('--------------------------------------------------------')
# Out:
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:10) --- 淨利數值: 64627.56
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:11) --- 淨利數值: 46020.96
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:12) --- 淨利數值: 56883.50
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:13) --- 淨利數值: 47189.04
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:14) --- 淨利數值: 45729.66
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:15) --- 淨利數值: 35230.24
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:16) --- 淨利數值: 26259.81
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:17) --- 淨利數值: 31945.99
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:18) --- 淨利數值: 43157.55
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:19) --- 淨利數值: 51131.27
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:20) --- 淨利數值: 36958.12
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:21) --- 淨利數值: -9410.96
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:22) --- 淨利數值: -8529.86
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:23) --- 淨利數值: -16503.58
# 2023-03-28, (EMA週期設定 = 短週期: 5,長週期:24) --- 淨利數值: -24559.41
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:10) --- 淨利數值: 42019.82
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:11) --- 淨利數值: 58380.35
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:12) --- 淨利數值: 53190.75
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:13) --- 淨利數值: 53396.78
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:14) --- 淨利數值: 31761.37
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:15) --- 淨利數值: 30260.94
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:16) --- 淨利數值: 52626.34
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:17) --- 淨利數值: 51131.27
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:18) --- 淨利數值: 36958.12
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:19) --- 淨利數值: -3553.42
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:20) --- 淨利數值: -8537.00
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:21) --- 淨利數值: -33864.39
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:22) --- 淨利數值: -39510.13
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:23) --- 淨利數值: -18719.72
# 2023-03-28, (EMA週期設定 = 短週期: 6,長週期:24) --- 淨利數值: -12718.01
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:10) --- 淨利數值: 58380.35
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:11) --- 淨利數值: 53396.78
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:12) --- 淨利數值: 44426.34
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:13) --- 淨利數值: 49766.50
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:14) --- 淨利數值: 48237.52
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:15) --- 淨利數值: 48625.20
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:16) --- 淨利數值: 36958.12
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:17) --- 淨利數值: 4448.86
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:18) --- 淨利數值: -3553.42
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:19) --- 淨利數值: -32015.13
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:20) --- 淨利數值: -43367.10
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:21) --- 淨利數值: -40510.42
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:22) --- 淨利數值: -13718.29
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:23) --- 淨利數值: -19200.22
# 2023-03-28, (EMA週期設定 = 短週期: 7,長週期:24) --- 淨利數值: -19200.22
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:10) --- 淨利數值: 57228.76
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:11) --- 淨利數值: 48258.32
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:12) --- 淨利數值: 53598.48
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:13) --- 淨利數值: 59903.99
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:14) --- 淨利數值: 44454.90
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:15) --- 淨利數值: 31956.70
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:16) --- 淨利數值: -4553.71
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:17) --- 淨利數值: -7097.26
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:18) --- 淨利數值: -40517.56
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:19) --- 淨利數值: -41373.67
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:20) --- 淨利數值: -23187.08
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:21) --- 淨利數值: -19200.22
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:22) --- 淨利數值: -19200.22
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:23) --- 淨利數值: -21724.14
# 2023-03-28, (EMA週期設定 = 短週期: 8,長週期:24) --- 淨利數值: -21724.14
# EMA短週期設定:5 EMA長週期設定:10
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 4
# 獲利損失次數比 : 42.86
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 3
# 淨利結算 : 67778.04
# 持有資產總值: 1064627.56
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:11
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 2
# 淨利結算 : 49171.44
# 持有資產總值: 1046020.96
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:12
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 60033.98
# 持有資產總值: 1056883.50
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:13
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 50339.51
# 持有資產總值: 1047189.04
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:14
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 48880.14
# 持有資產總值: 1045729.66
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:15
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 38380.72
# 持有資產總值: 1035230.24
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:16
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 29410.29
# 持有資產總值: 1026259.81
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:17
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 35096.46
# 持有資產總值: 1031945.99
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:18
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 46308.03
# 持有資產總值: 1043157.55
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:19
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 54281.75
# 持有資產總值: 1051131.27
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:20
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 40108.6
# 持有資產總值: 1036958.12
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:21
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 2
# 淨利結算 : -6260.48
# 持有資產總值: 990589.04
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:22
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -5379.38
# 持有資產總值: 991470.14
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:23
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -13353.1
# 持有資產總值: 983496.42
# --------------------------------------------------------
# EMA短週期設定:5 EMA長週期設定:24
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -21408.93
# 持有資產總值: 975440.59
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:10
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 2
# 淨利結算 : 45170.3
# 持有資產總值: 1042019.82
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:11
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 61530.83
# 持有資產總值: 1058380.35
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:12
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 56341.22
# 持有資產總值: 1053190.75
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:13
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 56547.26
# 持有資產總值: 1053396.78
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:14
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 34911.85
# 持有資產總值: 1031761.37
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:15
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 33411.43
# 持有資產總值: 1030260.94
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:16
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 55776.82
# 持有資產總值: 1052626.34
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:17
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 54281.75
# 持有資產總值: 1051131.27
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:18
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 40108.6
# 持有資產總值: 1036958.12
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:19
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -402.94
# 持有資產總值: 996446.58
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:20
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -5386.52
# 持有資產總值: 991463.00
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:21
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -30713.92
# 持有資產總值: 966135.61
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:22
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -36359.65
# 持有資產總值: 960489.87
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:23
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -15569.24
# 持有資產總值: 981280.28
# --------------------------------------------------------
# EMA短週期設定:6 EMA長週期設定:24
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -9567.53
# 持有資產總值: 987281.99
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:10
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 61530.83
# 持有資產總值: 1058380.35
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:11
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 56547.26
# 持有資產總值: 1053396.78
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:12
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 47576.82
# 持有資產總值: 1044426.34
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:13
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 52916.98
# 持有資產總值: 1049766.50
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:14
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 51388.0
# 持有資產總值: 1048237.52
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:15
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 3
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 51775.68
# 持有資產總值: 1048625.20
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:16
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 40108.6
# 持有資產總值: 1036958.12
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:17
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 7599.34
# 持有資產總值: 1004448.86
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:18
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -402.94
# 持有資產總值: 996446.58
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:19
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -28864.65
# 持有資產總值: 967984.87
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:20
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -40216.62
# 持有資產總值: 956632.90
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:21
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -37359.94
# 持有資產總值: 959489.58
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:22
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -10567.81
# 持有資產總值: 986281.71
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:23
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -16049.75
# 持有資產總值: 980799.78
# --------------------------------------------------------
# EMA短週期設定:7 EMA長週期設定:24
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -16049.75
# 持有資產總值: 980799.78
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:10
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 1
# 獲利損失次數比 : 75.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 60379.24
# 持有資產總值: 1057228.76
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:11
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 1
# 獲利損失次數比 : 75.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 51408.8
# 持有資產總值: 1048258.32
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:12
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 1
# 淨利結算 : 56748.96
# 持有資產總值: 1053598.48
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:13
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 63054.47
# 持有資產總值: 1059903.99
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:14
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 47605.38
# 持有資產總值: 1044454.90
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:15
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : 35107.18
# 持有資產總值: 1031956.70
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:16
# 策略運作分析結果:
# 獲利累積次數 : 3
# 損失累積次數 : 2
# 獲利損失次數比 : 60.0
# 最高連續獲利交易次數 : 3
# 最高連續損失交易次數 : 1
# 淨利結算 : -1403.23
# 持有資產總值: 995446.29
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:17
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -3946.78
# 持有資產總值: 992902.74
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:18
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 3
# 獲利損失次數比 : 40.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -37367.08
# 持有資產總值: 959482.44
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:19
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 4
# 獲利損失次數比 : 33.33
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -38223.19
# 持有資產總值: 958626.33
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:20
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -20036.61
# 持有資產總值: 976812.92
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:21
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -16049.75
# 持有資產總值: 980799.78
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:22
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -16049.75
# 持有資產總值: 980799.78
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:23
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -18573.66
# 持有資產總值: 978275.86
# --------------------------------------------------------
# EMA短週期設定:8 EMA長週期設定:24
# 策略運作分析結果:
# 獲利累積次數 : 2
# 損失累積次數 : 2
# 獲利損失次數比 : 50.0
# 最高連續獲利交易次數 : 2
# 最高連續損失交易次數 : 2
# 淨利結算 : -18573.66
# 持有資產總值: 978275.86
# --------------------------------------------------------
