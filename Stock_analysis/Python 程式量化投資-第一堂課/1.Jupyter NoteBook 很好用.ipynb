# %% [markdown]
# <h1>光頭傑夫製作</h1><img src="https://rolqiw.bl.files.1drv.com/y4mYqkObWmQmdJFd8pab8t8m7d_mFhh3_YG63fiAnPaG6gjahHFt0n087pF97x1W2wemm7hd4ZdiPD2OxoPtqcCD_4-Jy-fojnt97kGGWR4Hnq0-9Ny61afd7WVHVTmF_9pcr45OFDFSwLKByeQU1q9TjwKk-HsNmWVsW1eGQ4Gi-9G4pQ5DYoTxswYJ5r5dLF-kKsA1InEyrqmV3kF5pm4WQ?width=658&height=584&cropmode=none" width=160px align="left" />

# %% [markdown]
# ## [課程講義下載](http://lccn.io/TR0q2B)

# %% [markdown]
# # <span style="color:red ">cell主要分兩種
# ------
#
# *  ## Markdown
# *  ## Code--格子前面有In[ ]
# ----
# ![image-2.png](attachment:image-2.png)

# %%
2+4

# %% [markdown]
# # <span style="color:red ">Markdown的用法說明</span>
# ----

# %% [markdown]
# # <span style="color:green ">hashes (#)的用法
# ----
# #的個數決定你字體的大小

# %% [markdown]
#  # Sandy

# %% [markdown]
# ## <span style="color:green ">square [ ] and round brackets ( ) 讓你可以插入一個超連結

# %% [markdown]
# # [momo](https://www.momoshop.com.tw/main/Main.jsp)

# %% [markdown]
# # <span style="color:red ">點擊以後，你就可以改檔名

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <span style="color:red ">在Jupyter裡面插入影片</span>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('GZRJjwsd1k4')

# %% [markdown]
# # <span style="color:red ">你在程式碼的格子裡面，你也可以寫筆記!!
# ----------
#
# ##   只要你的每一行筆記前面加一個"#"

# %%
###############################

#這是我這個月的零用錢 3+3  

###############################
                   
3+9 #我喜歡這個

# %% [markdown]
# # <span style="color:red ">當然! 你也可以在Jupyter裡面插入照片! 沒錯是照片</span>
# ![image-12.png](attachment:image-12.png)

# %% [markdown]
# # <span style="color:red "> 大家都想要『上一步』，回到原狀

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 如果你不小心刪掉了某一格
# -----
# ## 先按esc
# ## 就可以進入cell的處理世界(也就是命令模式的狀態)
#
# ----
# ## 『上一步』是直接按Z

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 如果你是改碼的過程，讓你想要恢復上一步
# --------
# ##  當你的游標在cell裡面閃
# ## 那你是在cell內容編輯(編輯模式)的狀態
#
# ----
# ## 『上一步』是ctrl+Z

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style="color:red "> Jupyter 快捷鍵(Shortcut)列表

# %% [markdown]
# ### [參考連結](https://www.itread01.com/content/1532613367.html)

# %% [markdown]
# # <span style="color:red ">安裝工具模組-就用pip
# -------
# ## [PIP的模組網頁](https://pypi.org/project/yfinance/)

# %% [markdown]
# # <span style="color:red ">如果是第一次安裝

# %% [markdown]
# !pip install yfinance

# %% [markdown]
# # <span style="color:red ">如果是要更新安裝

# %%
# !pip install yfinance -U
#注意U要大寫喔!

# %%
# !pip show yfinance
